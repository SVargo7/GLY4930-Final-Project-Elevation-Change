# %% [markdown]
# # Final Project: Elevation Change Over Time
# ## Sydney Vargo

# %% [markdown]
# ## Imports

# %%
# imports 
import importlib # allows reloads for .py file
import graphingFunctions # .py file with graphing functions 

importlib.reload(graphingFunctions) # reload when .py file updated

# import functions
from graphingFunctions import twoDGraphing 
from graphingFunctions import threeDGraphing

# %% [markdown]
# ## Call 2D Function
#
# This is the first example of the 2D Graphing Function. It is called with Mid Ocean Ridge data.
#
# The template for the function arguments is as follows:
#
# twoDGraphing(filePathOld, filePathNew, north, south, east, west, oldDataYear, newDataYear)
#
# In order to run with new data, insert your filepaths, coordinates, and data collection years in the above order; the coordinates represent the bounds of your data, and must be the same for both the old and new data.

# %%
# 2D function, mid ocean ridge call

twoDGraphing("midOceanRidge/ridge2020data.tif", "midOceanRidge/ridge2026data.tif",
                               43.131, 35.663, -23.434, -33.299, 2020, 2026)

# %% [markdown]
# This is the second example of the 2D Graphing Function with a new set of coordinates and data. This uses Great Barrier Reef data. The function call again is:
#
# twoDGraphing(filePathOld, filePathNew, north, south, east, west, oldDataYear, newDataYear)

# %%
# 2D function, great barrier reef call

twoDGraphing("greatBarrierReef/reef2020data.tif", "greatBarrierReef/reef2026data.tif", 
             -9.08, -24.06, 152.42, 143.52, 2020, 2026)

# %% [markdown]
# ## Call 3D Function
#
# This is the first example of the 3D Graphing Function. It is called with the original Mid Ocean Ridge data.
#
# The template for the function arguments is the same as the 2D function, and is as follows:
#
# threeDGraphing(filePathOld, filePathNew, north, south, east, west, oldDataYear, newDataYear)

# %%
# 3D Function, Mid Ocean Ridge Call

threeDGraphing("midOceanRidge/ridge2020data.tif", "midOceanRidge/ridge2026data.tif",
                               43.131, 35.663, -23.434, -33.299, 2020, 2026)
# Out:
# Widget(value='<iframe src="http://localhost:49997/index.html?ui=P_0x31c4deae0_0&reconnect=auto" class="pyvista…
# Widget(value='<iframe src="http://localhost:49997/index.html?ui=P_0x3a18ca1e0_1&reconnect=auto" class="pyvista…
# Widget(value='<iframe src="http://localhost:49997/index.html?ui=P_0x3a75eaff0_2&reconnect=auto" class="pyvista…

# %% [markdown]
# This is the second example of the 3D Graphing Function. It is called with the Great Barrier Reef data. Once again, the template is:
#
# threeDGraphing(filePathOld, filePathNew, north, south, east, west, oldDataYear, newDataYear)

# %%
# 3D Function, Great Barrier Reef Call

threeDGraphing("greatBarrierReef/reef2020data.tif", "greatBarrierReef/reef2026data.tif", 
             -9.08, -24.06, 152.42, 143.52, 2020, 2026)
# Out:
# Widget(value='<iframe src="http://localhost:49997/index.html?ui=P_0x31dba0e60_3&reconnect=auto" class="pyvista…
# Widget(value='<iframe src="http://localhost:49997/index.html?ui=P_0x31d8e4e90_4&reconnect=auto" class="pyvista…
# Widget(value='<iframe src="http://localhost:49997/index.html?ui=P_0x31d8e7fb0_5&reconnect=auto" class="pyvista…
